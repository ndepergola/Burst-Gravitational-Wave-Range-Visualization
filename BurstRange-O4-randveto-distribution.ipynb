# %% [markdown]
# # Theory

# %% [markdown]
# This will be a good basis to make a function of the burst range over the range of frequencies cWB searches.  We are currently looking at the low frequency, short duration search is sensitive between 16-2084 Hz.
#
# The range is calculated (Eq. 30 from reference noted at cell bottom):
#
# \begin{equation}
# R_{eff} \approx \Big[ \frac{G}{2\pi^{2}c^{3}} \frac{E_{GW}}{S(f_{0})f_{0}^2\rho_{det}^{2}} \Big]^\frac{1}{2}
# \end{equation}
#
# where:
#
# - $S(f_{0})$ is the one-sided noise power spectrum (PSD)
# - $f_{0}$ is the central frequency of a narrowband signal
# - $\rho_{det}$ is the threshold SNR (detectable) [this willl be determined from the cWB background]
# - $E_{GW}$ is the energy emitted in graviational waves
#
# **Reference:**
#
# Sutton, Patrick, _"Rule of Thumb for the Detectability of Gravitational-Wave Bursts"_, arXiv:1304.0210v1, LIGO DCC# [P1000041-v3](https://dcc.ligo.org/LIGO-P1000041/public)

# %% [markdown]
# # Input Parameters:

# %%
import pdb # pdb.set_trace()  <- to insert breakpooint
import cWBtoolbox as cwb
import datetime
from gwpy.time import to_gps, from_gps
from gwpy.timeseries import TimeSeries
import pandas as pd
import numpy as np
import pickle
import os

#%set_env LIGO_DATAFIND_SERVER=ldr.ldas.cit:80
# %matplotlib inline

# define threshold (rate units: 1/yr, prob = (0 1]):
rateThresh = 100

# Define detector:
det = 0 # usually: 0 = L1, 1 = H1, 2 = V1
ifo = cwb.det2ifo(det)

# Specify if this run uses 'online' or 'offline' data:
on_off = 'online'  # O4a can only be processed as 'online' at present!

# Define minimum time for PSD:
minTime = 1200 # 600 for O3, 1200 for O4

# Define plot switch for background plots:
plot = False

# Define reference date:
gps_start = to_gps(datetime.datetime(2023, 7, 10, 0, 0, 0))
gps_start = gps_start.gpsSeconds

# Define time to proces WRT reference time:
startDays = 0
stopDays = startDays+1

# Path the location of predetermined unique segments:
path = '/home/nicole.depergola/jupyter/Nicole/O4a'
# !!!  Make this os.pwd()?

# Select only events that have slag=0 (matches detail file):
select = 'slag == 0'

# Define energy emitted in gravitational waves (for range calculations):
Egw = 1e-8 # solar masses (converted to J later)

# Define frequency range to calulate over:
flo = 32 # was 16 for O3, 32 for O4
fhi = 2048

# Path the veto segments, empty string skips this step:
veto_segs_path = f'{path}/vetoes/{ifo}/VETO_L1_O4A_LOUD-ACTIVE.txt'
#veto_segs_path = './electrical_vetoes_ER15-K01.txt' # for ER15
#veto_segs_path = '' # use this if not running vetoes
random_veto = True # True to generate rand veto segments matching those in veto_segs_path
trials = 1500 # must be at least 1 even if random_veto = False, this is ignored if random_veto = False

# Switch to cache PSDs over each day:
savePSD = True
# If there is already an existing cache, this switch will flip to False to avoid overwriting the cache

# Define switch to desplay progress:
verbose = True
if verbose:
    print('|| Input parameters loaded!')

    
# ===================================================================================
# Consistency check the above parameters:

# Make sure that if vetoes are NOT applied, other variable agree with this setting:
if not veto_segs_path:
    random_veto = False # if vetoes are not applied, we can't do a random veto run
    trials = 1 # only pass through data once
    
if not random_veto:
    trials = 1 # only pass through data once if no random vetoes
# Out:
# || Input parameters loaded!

# %% [markdown]
# # Calculate Burst Range:

# %%
# It is expected that this will process 1 day, but can process more...
for day in range(startDays,stopDays):
    
    # Is there a file of cached PSDs for the day?
    cachedPSD = False # by default, assume that PSDs need to be calculated from data
    
    # ================================================================= DAILY
    
    # Determine the GPS time for the given day WRT the reference date in gps_start:
    start = gps_start+(day*24*3600)
    stop = start+(24*3600)
    
    # Disable resurrection code:
    startHR = 0 
    rerun = False

    
    # Need this in datetime format to check the run:
    date = from_gps(start)

    
    if verbose:
        print('\n')
        print(f'*****  Processing date: {from_gps(start)}  *****')
        
    # Determine location of EVENTS file and background (live) file for this time:
    _, eventsfile, livefile = cwb.cwb_files(start, stop, on_off='online')
    
    if verbose:
        print('|| Get cWB daily events...')
    if os.path.exists(eventsfile):
        events = cwb.rdEVENTS(eventsfile)
        # Select desired SLAG:
        events = events.query(select)
    else:
        if verbose:
            print('-> NO DATA FOR THIS DAY.')
            print('----- MOVING TO NEXT DAY -----')
            continue
    if verbose:
        print('-> Done (EVENTS)')
    
    # Get background information from live file:
    if verbose:
        print('|| Get cWB background details (livetime ROOT file)...')
    live_out = f'live-{ifo}-{date.year:04.0f}-{date.month:02.0f}-{date.day:02.0f}.csv'
    # !!! Check if live_out exists; import that instead
    live = cwb.rdLiveROOT(livefile, path=path, out_file=live_out, SLAG=0)
    if verbose:
        print('-> Done (livetime)')
    
    # Determine unique segments:
    if verbose:
        print('|| Determining unique background segments...')
    uniqueFile = f'unique-{ifo}-{date.year:04.0f}-{date.month:02.0f}-{date.day:02.0f}.txt'
    # !!! Check if uniqueFile exists; import that instead
    unique = cwb.getUnique(live, det, path, outFile=True)
    if verbose:
        print('-> Done (unique background segments)')
        
    if not rerun:
        # Get DQ flags needed for plot segments bar (full day):
        if verbose:
            print('|| Get observing segments...')
        coincFile = f'coinc-{date.year}-{date.month}-{date.day}.p' # filag cache file
        if os.path.exists(coincFile): # load chached files
            saveFlags = pickle.load(open(coincFile, 'rb'))
            flag = saveFlags['flag']
            coincFlag = saveFlags['coincFlag']
        else: # fetch flags and save
            flag, coincFlag = cwb.getFlags(ifo, start, start+(24*3600)) # fetch
            saveFlags = {'flag':flag, 'coincFlag':coincFlag}
            pickle.dump(saveFlags, open(coincFile, 'wb')) # save
        if verbose:
            print('-> Done (observing segments)')
            
        R = [] # define holder variable for the burst range   
        DQflag = [] # initalize DQflag; not produced if no vetos, but saved at the end to it needs to exist or throws an error
    # !!! Check if this is a rerun and allow that
    
    # ================================================================= DAILY
    
    # Veto events if there is a path supplied:
    if veto_segs_path:
        if random_veto:
            if verbose:
                print(f'|| Randomly veto events comparible to using {veto_segs_path}...')
            
        else:
            if verbose:
                print(f'|| Veto events using {veto_segs_path}...')
           
        events, DQflag, _ = cwb.veto_events(events, veto_segs_path, ifo, random=random_veto, coincFlag=coincFlag, trials=trials, verbose=verbose, save=True)
        
        
    psdFile = f'PSD-{date.year}-{date.month}-{date.day}.p' # file name to cache PSDs for a day
    PSDhold = np.array([]) # initialize varible to hold PSDs to save later
    if os.path.exists(psdFile):
        savePSD = False # don't overwrite the cache file
        psd = pickle.load(open(psdFile, 'rb')) # load chached PSDs
        psd = psd['PSD']
        cachedPSD = True
        
    fname = cwb.mkfname(path, ifo, trials, date, veto_segs_path, random_veto, on_off) # file name to hold daily results
    
    # Loop through each hour in the day:
    for hour in range(startHR, 24):
        # Determine what hour is being worked on:
        if verbose:
            print(f'\n***  HOUR: {hour}  ***')
        hstart = start+(hour*3600) # GPS
        hstop = hstart+3600 
        
        # Determine SNR looking back 1 hour for 10 min segments within hour:
        if verbose:
            print(f'|| Get SNR at thresh rate {rateThresh}/yr...')
        # Look back 1 hour from the END of a 10 minute segment:
        snrStop = hstart + (np.array([1, 2, 3, 4, 5, 6])*600) # GPS
        snrStart = snrStop - 3600 # look back 1 hour
        nten = len(snrStop)
        
        snr = np.zeros([trials,nten]) # there are 6 10-minute segments in an hour
        for k in range(nten):
            if verbose:
                print(f'--- SNR: Looking back 1 hour from {from_gps(snrStop[k])}')
            
            snr[:,k] = cwb.getSNR(snrStart[k], snrStop[k], rateThresh, det, live, events, unique, plot=plot, verbose=verbose)
            
            
        if not np.isnan(snr).all():
            if cachedPSD:
                PSD = psd[hour*6:(hour*6)+6,:] # select PSD data for this hour
                FFTlen = 8
                f = np.arange(0, (16384/2)+(FFTlen**-1), (FFTlen**-1))
                # Find indices where f > flo:
                nlo = np.where(f >= flo)
                # find indices where f >= fhi:
                nhi = np.where(f < fhi)
                # Find indecies where f > flo AND f >= fhi:
                ndx = np.intersect1d(nlo,nhi)
                f = f[ndx]
            else:
                # Get full hour of strain data:
                if verbose:
                    print(f'|| Get full hour of strain data...')
                data = TimeSeries.get(f'{ifo}:GDS-CALIB_STRAIN', hstart, hstop, pad=0, verbose=verbose, allow_tape=True)

                # Get PSD in 10 minute intervals:
                if verbose:
                    print(f'|| Get 10 min PSDs for this hour...')
                PSD, f, flagStat = cwb.getPSD(data, ifo, coincFlag, flo=flo, fhi=fhi, verbose=verbose)
                
        else:
            if verbose:
                print(f'|| No SNRs for this hour; skip getting data...')
            FFTlen = 8
            PSDlen = int((16384*(FFTlen/2))+1)
            PSD = np.zeros([nten, PSDlen])
            f = np.arange(0, (16384/2)+(FFTlen**-1), (FFTlen**-1))
            PSD, f = cwb.select_f(PSD, f, flo, fhi)
            
        if savePSD:
            # Add this hour's PSDs to the full day's PSDs:
            if len(PSDhold) == 0:
                PSDhold = PSD
            else:
                PSDhold = np.vstack([PSDhold, PSD])
        
        # The burst range calculations needs SNR and what cWB reports is SNR**2:
        snr = np.sqrt(snr)
        # Caluclate R WRT frequency for each 10 min segment:
        if verbose:
            print(f'|| Calulate burst range...')
        if trials == 1: # no random veto trials
            SNR = snr[0]
            if len(R) == 0: # if this is the first 10 min, then fill R with the range array (establish number of columns)
                R = cwb.brange(PSD, f, SNR, Egw)
            else: # if number of columns in R is established, then append rows to it
                R = np.vstack([R, cwb.brange(PSD, f, SNR, Egw)])
        else: # there are multiple random veto trials
            for trial in range(trials): # loop over the trials
                SNR = snr[trial,:] # select the SNRs for this trial
                if len(R) == 0: # if this is the first 10 min, then fill R with the range dict (establish number of columns)
                    R = {str(trial): cwb.brange(PSD, f, SNR, Egw)}
                elif str(trial) in R: # check if a key exists in dict
                    R.update({str(trial): np.vstack([R[str(trial)], cwb.brange(PSD, f, SNR, Egw)])}) # append new values
                else:
                    R[str(trial)] = cwb.brange(PSD, f, SNR, Egw) # create new key for next trial
        
        # Save intermediate results [since Jupyter loves to yeet my buffer :( ]:
        if verbose:
            print(f'|| Save results to file [{fname}]...')
        burstRange = {'R':R, 'f':f, 'flag':flag, 'coincFlag':coincFlag, 'ifo':ifo}
        pickle.dump(burstRange, open(fname, 'wb'))
    # END loop over hours in a day

    # Make plot of range(F,T) with segments bar:
    if verbose:
        print('|| Plot results...')
    T, F, t, meanRange = cwb.plot_brange(R, f, start, ifo, flag, coincFlag, path)

    
    if savePSD:
        # Cache PSDs for the day
        saveme = {'PSD':PSDhold}
        pickle.dump(saveme, open(f'PSD-{date.year}-{date.month}-{date.day}.p','wb'))

    # Save final results:
    if verbose:
        print(f'|| Save results to file [{fname}]...')
    burstRange = {'R':R, 'T':T, 'F':F, 't':t, 'f':f, 'flag':flag, 'coincFlag':coincFlag, 'ifo':ifo, 'meanRange':meanRange, 'DQflag':DQflag, 'veto_segs_path':veto_segs_path, 'random_veto':random_veto}
    pickle.dump(burstRange, open(fname, 'wb'))
    
    

# END loop over a single day

if verbose:
    print('----- BURST RANGE CALCULATIONS COMPLETE -----')
# END loop over days
# Out:
# *****  Processing date: 2023-07-12 00:00:00  *****
# Run: O4a
# || Get cWB daily events...
# -> Done (EVENTS)
# || Get cWB background details (livetime ROOT file)...
# -- Loading ROOT file...
# -- Slect SLAG...
# -- Write selected SLAG to pd.DataFrame...
# -- Write livetime data to /home/nicole.depergola/jupyter/Nicole/O4a/live-L1-2023-07-12.csv
# -> Done (livetime)
# || Determining unique background segments...
# -- Write unique background segments to /home/nicole.depergola/jupyter/Nicole/O4a/L1/unique-L1-2023-7-12.txt
# -> Done (unique background segments)
# || Get observing segments...
# -> Done (observing segments)
# || Randomly veto events comparible to using /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1/VETO_L1_O4A_LOUD-ACTIVE.txt...
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -- Simulating random vetoes: 1500 trials
# -> Trial 0000 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0001 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0002 done: 0.07% of events vetoed (N = 5).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0003 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0004 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0005 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0006 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0007 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0008 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0009 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0010 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0011 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0012 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0013 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0014 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0015 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0016 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0017 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0018 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0019 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0020 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0021 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0022 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0023 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0024 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0025 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0026 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0027 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0028 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0029 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0030 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0031 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0032 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0033 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0034 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0035 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0036 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0037 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0038 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0039 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0040 done: 0.11% of events vetoed (N = 8).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0041 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0042 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0043 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0044 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0045 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0046 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0047 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0048 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0049 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0050 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0051 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0052 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0053 done: 0.28% of events vetoed (N = 21).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0054 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0055 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0056 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0057 done: 0.08% of events vetoed (N = 6).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0058 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0059 done: 0.17% of events vetoed (N = 13).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0060 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0061 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0062 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0063 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0064 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0065 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0066 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0067 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0068 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0069 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0070 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0071 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0072 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0073 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0074 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0075 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0076 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0077 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0078 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0079 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0080 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0081 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0082 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0083 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0084 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0085 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0086 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0087 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0088 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0089 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0090 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0091 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0092 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0093 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0094 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0095 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0096 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0097 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0098 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0099 done: 0.08% of events vetoed (N = 6).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0100 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0101 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0102 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0103 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0104 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0105 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0106 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0107 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0108 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0109 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0110 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0111 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0112 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0113 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0114 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0115 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0116 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0117 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0118 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0119 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0120 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0121 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0122 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0123 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0124 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0125 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0126 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0127 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0128 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0129 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0130 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0131 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0132 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0133 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0134 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0135 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0136 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0137 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0138 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0139 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0140 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0141 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0142 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0143 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0144 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0145 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0146 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0147 done: 0.07% of events vetoed (N = 5).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0148 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0149 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0150 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0151 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0152 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0153 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0154 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0155 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0156 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0157 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0158 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0159 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0160 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0161 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0162 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0163 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0164 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0165 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0166 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0167 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0168 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0169 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0170 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0171 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0172 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0173 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0174 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0175 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0176 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0177 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0178 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0179 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0180 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0181 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0182 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0183 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0184 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0185 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0186 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0187 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0188 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0189 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0190 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0191 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0192 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0193 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0194 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0195 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0196 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0197 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0198 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0199 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0200 done: 0.07% of events vetoed (N = 5).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0201 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0202 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0203 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0204 done: 0.07% of events vetoed (N = 5).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0205 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0206 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0207 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0208 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0209 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0210 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0211 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0212 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0213 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0214 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0215 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0216 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0217 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0218 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0219 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0220 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0221 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0222 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0223 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0224 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0225 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0226 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0227 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0228 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0229 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0230 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0231 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0232 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0233 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0234 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0235 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0236 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0237 done: 0.11% of events vetoed (N = 8).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0238 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0239 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0240 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0241 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0242 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0243 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0244 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0245 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0246 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0247 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0248 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0249 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0250 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0251 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0252 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0253 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0254 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0255 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0256 done: 0.09% of events vetoed (N = 7).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0257 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0258 done: 0.07% of events vetoed (N = 5).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0259 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0260 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0261 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0262 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0263 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0264 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0265 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0266 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0267 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0268 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0269 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0270 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0271 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0272 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0273 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0274 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0275 done: 0.08% of events vetoed (N = 6).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0276 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0277 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0278 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0279 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0280 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0281 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0282 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0283 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0284 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0285 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0286 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0287 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0288 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0289 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0290 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0291 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0292 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0293 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0294 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0295 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0296 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0297 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0298 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0299 done: 0.11% of events vetoed (N = 8).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0300 done: 0.15% of events vetoed (N = 11).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0301 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0302 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0303 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0304 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0305 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0306 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0307 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0308 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0309 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0310 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0311 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0312 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0313 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0314 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0315 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0316 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0317 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0318 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0319 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0320 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0321 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0322 done: 0.08% of events vetoed (N = 6).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0323 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0324 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0325 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0326 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0327 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0328 done: 0.07% of events vetoed (N = 5).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0329 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0330 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0331 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0332 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0333 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0334 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0335 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0336 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0337 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0338 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0339 done: 0.09% of events vetoed (N = 7).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0340 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0341 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0342 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0343 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0344 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0345 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0346 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0347 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0348 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0349 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0350 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0351 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0352 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0353 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0354 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0355 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0356 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0357 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0358 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0359 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0360 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0361 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0362 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0363 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0364 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0365 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0366 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0367 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0368 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0369 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0370 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0371 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0372 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0373 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0374 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0375 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0376 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0377 done: 0.09% of events vetoed (N = 7).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0378 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0379 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0380 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0381 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0382 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0383 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0384 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0385 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0386 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0387 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0388 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0389 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0390 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0391 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0392 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0393 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0394 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0395 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0396 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0397 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0398 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0399 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0400 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0401 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0402 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0403 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0404 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0405 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0406 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0407 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0408 done: 0.07% of events vetoed (N = 5).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0409 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0410 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0411 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0412 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0413 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0414 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0415 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0416 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0417 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0418 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0419 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0420 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0421 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0422 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0423 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0424 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0425 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0426 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0427 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0428 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0429 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0430 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0431 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0432 done: 0.05% of events vetoed (N = 4).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0433 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0434 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0435 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0436 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0437 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0438 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0439 done: 0.08% of events vetoed (N = 6).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0440 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0441 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0442 done: 0.04% of events vetoed (N = 3).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0443 done: 0.03% of events vetoed (N = 2).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0444 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0445 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0446 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0447 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0448 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0449 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0450 done: 0.01% of events vetoed (N = 1).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0451 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0452 done: 0.00% of events vetoed (N = 0).
# /home/nicole.depergola/jupyter/Nicole/O4a/vetoes/L1
# -> Trial 0453 done: 0.01% of events vetoed (N = 1).
# ...
# --- SNR: Looking back 1 hour from 2023-07-12 08:40:00
# -> background time = 5757600.0
# -> zero-lag time = 2400.0
# -> SNR = [62. 62. 62. ... 62. 62. 62.]
# --- SNR: Looking back 1 hour from 2023-07-12 08:50:00
# -> background time = 2878800.0
# -> zero-lag time = 1200.0
# -> SNR = [64. 64. 64. ... 64. 64. 64.]
# --- SNR: Looking back 1 hour from 2023-07-12 09:00:00
# -> background time = 2878800.0
# -> zero-lag time = 1200.0
# -> SNR = [64. 64. 64. ... 64. 64. 64.]
# || Calulate burst range...
# || Save results to file [/home/nicole.depergola/jupyter/Nicole/O4a/L1/brange-daily-rvetoed-1500-L1-2023-07-12.p]...
#
# ***  HOUR: 9  ***
# || Get SNR at thresh rate 100/yr...
# --- SNR: Looking back 1 hour from 2023-07-12 09:10:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 09:20:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 09:30:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 09:40:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 09:50:00
# -> background time = 2878800.0
# -> zero-lag time = 1200.0
# -> SNR = [112. 112. 112. ... 112. 112. 112.]
# --- SNR: Looking back 1 hour from 2023-07-12 10:00:00
# -> background time = 2878800.0
# -> zero-lag time = 1200.0
# -> SNR = [112. 112. 112. ... 112. 112. 112.]
# || Calulate burst range...
# || Save results to file [/home/nicole.depergola/jupyter/Nicole/O4a/L1/brange-daily-rvetoed-1500-L1-2023-07-12.p]...
#
# ***  HOUR: 10  ***
# || Get SNR at thresh rate 100/yr...
# --- SNR: Looking back 1 hour from 2023-07-12 10:10:00
# -> background time = 5757600.0
# -> zero-lag time = 2400.0
# -> SNR = [87. 87. 87. ... 87. 87. 87.]
# --- SNR: Looking back 1 hour from 2023-07-12 10:20:00
# -> background time = 5757600.0
# -> zero-lag time = 2400.0
# -> SNR = [87. 87. 87. ... 87. 87. 87.]
# --- SNR: Looking back 1 hour from 2023-07-12 10:30:00
# -> background time = 5757600.0
# -> zero-lag time = 2400.0
# -> SNR = [76. 76. 76. ... 76. 76. 76.]
# --- SNR: Looking back 1 hour from 2023-07-12 10:40:00
# -> background time = 5757600.0
# -> zero-lag time = 2400.0
# -> SNR = [76. 76. 76. ... 76. 76. 76.]
# --- SNR: Looking back 1 hour from 2023-07-12 10:50:00
# -> background time = 5757600.0
# -> zero-lag time = 2400.0
# -> SNR = [71. 71. 71. ... 71. 71. 71.]
# --- SNR: Looking back 1 hour from 2023-07-12 11:00:00
# -> background time = 5757600.0
# -> zero-lag time = 2400.0
# -> SNR = [71. 71. 71. ... 71. 71. 71.]
# || Calulate burst range...
# || Save results to file [/home/nicole.depergola/jupyter/Nicole/O4a/L1/brange-daily-rvetoed-1500-L1-2023-07-12.p]...
#
# ***  HOUR: 11  ***
# || Get SNR at thresh rate 100/yr...
# --- SNR: Looking back 1 hour from 2023-07-12 11:10:00
# -> background time = 2878800.0
# -> zero-lag time = 1200.0
# -> SNR = [66. 66. 66. ... 66. 66. 66.]
# --- SNR: Looking back 1 hour from 2023-07-12 11:20:00
# -> background time = 2878800.0
# -> zero-lag time = 1200.0
# -> SNR = [66. 66. 66. ... 66. 66. 66.]
# --- SNR: Looking back 1 hour from 2023-07-12 11:30:00
# -> background time = 2878800.0
# -> zero-lag time = 1200.0
# -> SNR = [62. 62. 62. ... 62. 62. 62.]
# --- SNR: Looking back 1 hour from 2023-07-12 11:40:00
# -> background time = 2878800.0
# -> zero-lag time = 1200.0
# -> SNR = [62. 62. 62. ... 62. 62. 62.]
# --- SNR: Looking back 1 hour from 2023-07-12 11:50:00
# -> background time = 5757600.0
# -> zero-lag time = 2400.0
# -> SNR = [68. 68. 68. ... 68. 68. 68.]
# --- SNR: Looking back 1 hour from 2023-07-12 12:00:00
# -> background time = 5757600.0
# -> zero-lag time = 2400.0
# -> SNR = [68. 68. 68. ... 68. 68. 68.]
# || Calulate burst range...
# || Save results to file [/home/nicole.depergola/jupyter/Nicole/O4a/L1/brange-daily-rvetoed-1500-L1-2023-07-12.p]...
#
# ***  HOUR: 12  ***
# || Get SNR at thresh rate 100/yr...
# --- SNR: Looking back 1 hour from 2023-07-12 12:10:00
# -> background time = 5757600.0
# -> zero-lag time = 2400.0
# -> SNR = [122. 122. 122. ... 122. 122. 122.]
# --- SNR: Looking back 1 hour from 2023-07-12 12:20:00
# -> background time = 5757600.0
# -> zero-lag time = 2400.0
# -> SNR = [122. 122. 122. ... 122. 122. 122.]
# --- SNR: Looking back 1 hour from 2023-07-12 12:30:00
# -> background time = 2878800.0
# -> zero-lag time = 1200.0
# -> SNR = [132. 132. 132. ... 132. 132. 132.]
# --- SNR: Looking back 1 hour from 2023-07-12 12:40:00
# -> background time = 2878800.0
# -> zero-lag time = 1200.0
# -> SNR = [132. 132. 132. ... 132. 132. 132.]
# --- SNR: Looking back 1 hour from 2023-07-12 12:50:00
# -> background time = 2878800.0
# -> zero-lag time = 1200.0
# -> SNR = [77. 77. 77. ... 77. 77. 77.]
# --- SNR: Looking back 1 hour from 2023-07-12 13:00:00
# -> background time = 2878800.0
# -> zero-lag time = 1200.0
# -> SNR = [77. 77. 77. ... 77. 77. 77.]
# || Calulate burst range...
# || Save results to file [/home/nicole.depergola/jupyter/Nicole/O4a/L1/brange-daily-rvetoed-1500-L1-2023-07-12.p]...
#
# ***  HOUR: 13  ***
# || Get SNR at thresh rate 100/yr...
# --- SNR: Looking back 1 hour from 2023-07-12 13:10:00
# -> background time = 5757600.0
# -> zero-lag time = 2400.0
# -> SNR = [102. 102. 102. ... 102. 102. 102.]
# --- SNR: Looking back 1 hour from 2023-07-12 13:20:00
# -> background time = 5757600.0
# -> zero-lag time = 2400.0
# -> SNR = [102. 102. 102. ... 102. 102. 102.]
# --- SNR: Looking back 1 hour from 2023-07-12 13:30:00
# -> background time = 2878800.0
# -> zero-lag time = 1200.0
# -> SNR = [102. 102. 102. ... 102. 102. 102.]
# --- SNR: Looking back 1 hour from 2023-07-12 13:40:00
# -> background time = 2878800.0
# -> zero-lag time = 1200.0
# -> SNR = [102. 102. 102. ... 102. 102. 102.]
# --- SNR: Looking back 1 hour from 2023-07-12 13:50:00
# -> background time = 2878800.0
# -> zero-lag time = 1200.0
# -> SNR = [112. 112. 112. ... 112. 112. 112.]
# --- SNR: Looking back 1 hour from 2023-07-12 14:00:00
# -> background time = 2878800.0
# -> zero-lag time = 1200.0
# -> SNR = [112. 112. 112. ... 112. 112. 112.]
# || Calulate burst range...
# || Save results to file [/home/nicole.depergola/jupyter/Nicole/O4a/L1/brange-daily-rvetoed-1500-L1-2023-07-12.p]...
#
# ***  HOUR: 14  ***
# || Get SNR at thresh rate 100/yr...
# --- SNR: Looking back 1 hour from 2023-07-12 14:10:00
# -> background time = 5757600.0
# -> zero-lag time = 2400.0
# -> SNR = [122. 122. 122. ... 122. 122. 122.]
# --- SNR: Looking back 1 hour from 2023-07-12 14:20:00
# -> background time = 5757600.0
# -> zero-lag time = 2400.0
# -> SNR = [122. 122. 122. ... 122. 122. 122.]
# --- SNR: Looking back 1 hour from 2023-07-12 14:30:00
# -> background time = 5757600.0
# -> zero-lag time = 2400.0
# -> SNR = [94. 94. 94. ... 94. 94. 94.]
# --- SNR: Looking back 1 hour from 2023-07-12 14:40:00
# -> background time = 5757600.0
# -> zero-lag time = 2400.0
# -> SNR = [94. 94. 94. ... 94. 94. 94.]
# --- SNR: Looking back 1 hour from 2023-07-12 14:50:00
# -> background time = 2878800.0
# -> zero-lag time = 1200.0
# -> SNR = [67. 67. 67. ... 67. 67. 67.]
# --- SNR: Looking back 1 hour from 2023-07-12 15:00:00
# -> background time = 2878800.0
# -> zero-lag time = 1200.0
# -> SNR = [67. 67. 67. ... 67. 67. 67.]
# || Calulate burst range...
# /cvmfs/software.igwn.org/conda/envs/igwn-py38/lib/python3.8/site-packages/astropy/units/quantity.py:673: RuntimeWarning: divide by zero encountered in divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# || Save results to file [/home/nicole.depergola/jupyter/Nicole/O4a/L1/brange-daily-rvetoed-1500-L1-2023-07-12.p]...
#
# ***  HOUR: 15  ***
# || Get SNR at thresh rate 100/yr...
# --- SNR: Looking back 1 hour from 2023-07-12 15:10:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 15:20:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 15:30:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 15:40:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 15:50:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 16:00:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# || No SNRs for this hour; skip getting data...
# || Calulate burst range...
# || Save results to file [/home/nicole.depergola/jupyter/Nicole/O4a/L1/brange-daily-rvetoed-1500-L1-2023-07-12.p]...
#
# ***  HOUR: 16  ***
# || Get SNR at thresh rate 100/yr...
# --- SNR: Looking back 1 hour from 2023-07-12 16:10:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 16:20:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 16:30:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 16:40:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 16:50:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 17:00:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# || No SNRs for this hour; skip getting data...
# || Calulate burst range...
# || Save results to file [/home/nicole.depergola/jupyter/Nicole/O4a/L1/brange-daily-rvetoed-1500-L1-2023-07-12.p]...
#
# ***  HOUR: 17  ***
# || Get SNR at thresh rate 100/yr...
# --- SNR: Looking back 1 hour from 2023-07-12 17:10:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 17:20:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 17:30:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 17:40:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 17:50:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 18:00:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# || No SNRs for this hour; skip getting data...
# || Calulate burst range...
# || Save results to file [/home/nicole.depergola/jupyter/Nicole/O4a/L1/brange-daily-rvetoed-1500-L1-2023-07-12.p]...
#
# ***  HOUR: 18  ***
# || Get SNR at thresh rate 100/yr...
# --- SNR: Looking back 1 hour from 2023-07-12 18:10:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 18:20:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 18:30:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 18:40:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 18:50:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 19:00:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# || No SNRs for this hour; skip getting data...
# || Calulate burst range...
# || Save results to file [/home/nicole.depergola/jupyter/Nicole/O4a/L1/brange-daily-rvetoed-1500-L1-2023-07-12.p]...
#
# ***  HOUR: 19  ***
# || Get SNR at thresh rate 100/yr...
# --- SNR: Looking back 1 hour from 2023-07-12 19:10:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 19:20:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 19:30:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 19:40:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 19:50:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 20:00:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# || No SNRs for this hour; skip getting data...
# || Calulate burst range...
# || Save results to file [/home/nicole.depergola/jupyter/Nicole/O4a/L1/brange-daily-rvetoed-1500-L1-2023-07-12.p]...
#
# ***  HOUR: 20  ***
# || Get SNR at thresh rate 100/yr...
# --- SNR: Looking back 1 hour from 2023-07-12 20:10:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 20:20:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 20:30:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 20:40:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 20:50:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 21:00:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# || No SNRs for this hour; skip getting data...
# || Calulate burst range...
# || Save results to file [/home/nicole.depergola/jupyter/Nicole/O4a/L1/brange-daily-rvetoed-1500-L1-2023-07-12.p]...
#
# ***  HOUR: 21  ***
# || Get SNR at thresh rate 100/yr...
# --- SNR: Looking back 1 hour from 2023-07-12 21:10:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 21:20:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 21:30:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 21:40:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 21:50:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 22:00:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# || No SNRs for this hour; skip getting data...
# || Calulate burst range...
# || Save results to file [/home/nicole.depergola/jupyter/Nicole/O4a/L1/brange-daily-rvetoed-1500-L1-2023-07-12.p]...
#
# ***  HOUR: 22  ***
# || Get SNR at thresh rate 100/yr...
# --- SNR: Looking back 1 hour from 2023-07-12 22:10:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 22:20:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 22:30:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 22:40:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 22:50:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 23:00:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# || No SNRs for this hour; skip getting data...
# || Calulate burst range...
# || Save results to file [/home/nicole.depergola/jupyter/Nicole/O4a/L1/brange-daily-rvetoed-1500-L1-2023-07-12.p]...
#
# ***  HOUR: 23  ***
# || Get SNR at thresh rate 100/yr...
# --- SNR: Looking back 1 hour from 2023-07-12 23:10:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 23:20:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 23:30:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 23:40:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-12 23:50:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# --- SNR: Looking back 1 hour from 2023-07-13 00:00:00
# -> background time = 0.0
# -> zero-lag time = 0.0
# -> no events
# || No SNRs for this hour; skip getting data...
# || Calulate burst range...
# || Save results to file [/home/nicole.depergola/jupyter/Nicole/O4a/L1/brange-daily-rvetoed-1500-L1-2023-07-12.p]...
# || Plot results...
# || Save results to file [/home/nicole.depergola/jupyter/Nicole/O4a/L1/brange-daily-rvetoed-1500-L1-2023-07-12.p]...
# ----- BURST RANGE CALCULATIONS COMPLETE -----

# %% [markdown]
# # Load random veto results from file (this can take a while!)

# %%
# Load parameters above before this cell!

day = 0
date = from_gps(gps_start+(day*24*3600))


rpath = f'./{ifo}/brange-daily-rvetoed-1500-{ifo}-{date.year:04.0f}-{date.month:02.0f}-{date.day:02.0f}.p'
burstRange = pickle.load(open(rpath, 'rb'))
meanRange = burstRange['meanRange']
test = np.mean(meanRange, axis=1)

hold = []
hold = np.append(hold, test)


rpath = f'./{ifo}/brange-daily-rvetoed-2000-{ifo}-{date.year:04.0f}-{date.month:02.0f}-{date.day:02.0f}.p'
burstRange = pickle.load(open(rpath, 'rb'))
meanRange = burstRange['meanRange']
test = np.mean(meanRange, axis=1)


hold = np.append(hold, test)

test = hold

burstRange = []



vpath = f'./{ifo}/brange-daily-vetoed-{ifo}-{date.year:04.0f}-{date.month:02.0f}-{date.day:02.0f}.p'
burstRange = pickle.load(open(vpath, 'rb'))
meanRange = burstRange['meanRange']
trueVeto = np.mean(meanRange, axis=1)



path = f'./{ifo}/brange-daily-{ifo}-{date.year:04.0f}-{date.month:02.0f}-{date.day:02.0f}.p'
burstRange = pickle.load(open(path, 'rb'))
meanRange = burstRange['meanRange']
noVeto = np.mean(meanRange, axis=1)

burstRange = []
meanRange = []

# %% [markdown]
# ## Save just the results we need to a single file for faster reloading later...

# %%
meanRange = {'noVeto':noVeto, 'trueVeto':trueVeto, 'test':test}
pickle.dump(meanRange, open(f'./{ifo}/meanRange-rveto-{date.year:04.0f}-{date.month:02.0f}-{date.day:02.0f}.p', 'wb'))

# %% [markdown]
# # Load results to analyze distribution from random vetos to measure significance of result from true veotoes

# %%
day = 0
date = from_gps(gps_start+(day*24*3600))

ifo = 'L1'

meanRange = pickle.load(open(f'./{ifo}/meanRange-rveto-{date.year:04.0f}-{date.month:02.0f}-{date.day:02.0f}.p', 'rb'))
noVeto = meanRange['noVeto']
trueVeto = meanRange['trueVeto']
test = meanRange['test']

# %% [markdown]
# ## Look at full results (There shouldn't be results below 8.59 kpc! Look into this!)

# %% [markdown]
# Bug most likely in cWBtoolbox -> getSNR()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(12,6))
count, bins, _ = plt.hist(test, 30, density=True, log=True, label=f'random vetoes')

midbins = (np.diff(bins)/2)+bins[:-1]
fitx = midbins[16:]
#a, b = np.polyfit(fitx, np.log(count[16:]),  1, w=np.sqrt(count[16:]))
a, b = np.polyfit((fitx)**2, np.log(count[16:]),  1)
# You may run into fitting problems if a bin has no counts in it!  Consider variable bin size?
fity = np.exp(a*fitx**2) * np.exp(b)

plt.axvline(noVeto, color='g', label='no veto')
plt.axvline(trueVeto, color='r', label='true veto')
plt.plot(fitx, fity, label=f'fit = exp({a:02.2f}*x)*exp({b:0.2f})')
plt.legend()
plt.xlabel('Range [kpc]')
plt.ylabel('Density')
plt.suptitle(f'Range Distribution using Random Vetoes (N = {len(test)}) for {date.year:04.0f}-{date.month:02.0f}-{date.day:02.0f}')
mu = np.mean(test)
std = np.std(test)
sterr = std/np.sqrt(len(test))
plt.title(f'The mean range for {len(test)} trials is {mu:0.3f} +/- {sterr:0.3e} kpc.')
         

print(f'The mean range for {len(test)} trials is {mu:0.3f} +/- {sterr:0.3e} kpc.')
plt.savefig(f'./vetoes/{ifo}/range_dist-rvetoes-{date.year:04.0f}-{date.month:02.0f}-{date.day:02.0f}.png')
# Out:
# /tmp/ipykernel_1740194/2867222552.py:10: RuntimeWarning: divide by zero encountered in log
#   a, b = np.polyfit((fitx)**2, np.log(count[16:]),  1)
# The mean range for 3500 trials is 7.591 +/- 1.130e-04 kpc.
